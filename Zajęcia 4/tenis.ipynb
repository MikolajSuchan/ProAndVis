# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tennis_title=[24,22,20,14]
another_plot=pd.Series(tennis_title)
another_plot.index=['Novak Djokovic','Rafael Nadal','Roger Federer','Pete Sampras']
another_plot.plot(kind='bar',title='Grand Slam Tournament',xlabel='Tennis Players',ylabel='How many titles players won')
# Out:
# <Axes: title={'center': 'Grand Slam Tournament'}, xlabel='Tennis Players', ylabel='How many titles players won'>
